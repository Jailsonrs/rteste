# %%
library(datasets)
library(dplyr)
library(ggplot2)
library('ggfortify')

# %%
AirPassengers %>% data.frame() -> AirPassengerst 
colnames(AirPassengerst) <- "value"
str(AirPassengers)$
# Out:
#  Time-Series [1:144] from 1949 to 1961: 112 118 132 129 121 135 148 148 136 119 ...

# %%
autoplot(AirPassengers,colour = "white",)+
    labs(title="Ts plot for AirPassengens data")+
    theme(plot.title = element_text(size=19,colour="grey90"),
          panel.background = element_rect(fill = "black"),
          panel.grid = element_blank(),
         plot.background = element_rect(fill="black"),
         axis.line     = element_line(colour="white"))
# Out:
# plot without title

# %%
AirPassengerst %>%
    ggplot(aes(x=1:length(value),y=value))+geom_path()
# Out:
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
# plot without title
